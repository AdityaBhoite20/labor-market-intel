# %%
import shutil
import os

os.makedirs("../data/curated", exist_ok=True)

# %%
curated_files = [
    "oews_all_occupations_2015_2025.csv",
    "master_occupations.csv",
    "occupation_clusters.csv",
    "employment_forecast_2030_2035.csv",
    "forecast_vs_bls_comparison.csv",
    "ai_exposure_scores.csv",
    "ai_exposure_vs_growth.csv",
    "ces_industry_trends_clean.csv",
    "laus_state_trends_clean.csv",
    "job_title_clusters.csv",
    "full_skill_wage_analysis.csv",
]

for filename in curated_files:
    shutil.copy(f"../data/processed/{filename}", f"../data/curated/{filename}")
    print(f"Copied {filename}")
# Out:
# Copied oews_all_occupations_2015_2025.csv
# Copied master_occupations.csv
# Copied occupation_clusters.csv
# Copied employment_forecast_2030_2035.csv
# Copied forecast_vs_bls_comparison.csv
# Copied ai_exposure_scores.csv
# Copied ai_exposure_vs_growth.csv
# Copied ces_industry_trends_clean.csv
# Copied laus_state_trends_clean.csv
# Copied job_title_clusters.csv
# Copied full_skill_wage_analysis.csv
